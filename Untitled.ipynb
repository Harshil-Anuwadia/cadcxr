# %%
from bin.dicom_api import *

# %%
path = "/home/harshilanuwadia/CAD-CXR/raw_data/037503b94eb68a16587a78bce365e681.dicom"

# %%
read_dcm(path)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 156
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002,0003) Media Storage SOP Instance UID      UI: 037503b94eb68a16587a78bce365e681
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.3.4
# (0002,0013) Implementation Version Name         SH: ''
# (0002,0016) Source Application Entity Title     AE: 'VITREA1'
# -------------------------------------------------
# (0010,0040) Patient's Sex                       CS: ''
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0010) Rows                                US: 2721
# (0028,0011) Columns                             US: 2322
# ...

# %%
explain(path)
# Out:
# ══════════════════════════════════════════════════════════════════════
#   DICOM DIAGNOSTIC REPORT — 037503b94eb68a16587a78bce365e681.dicom
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
#   OVERVIEW
# ──────────────────────────────────────────────────────────────────────
#   File         : 037503b94eb68a16587a78bce365e681.dicom  (12.05 MB)
#   Valid DICOM  : True   Has Pixels : True
#   Modality     : None   View : None
#   Dimensions   : 2721 × 2322  (non-square)
#   Photometric  : MONOCHROME2   Bits stored : 12
#   Rescale      : slope=1.0  intercept=0.0  ✓ none
#   Windowing    : center=1631.0  width=4260.0
#
# ──────────────────────────────────────────────────────────────────────
#   ISSUES FOUND (1)
# ──────────────────────────────────────────────────────────────────────
#   • [INFO] Non-square image
#
# ──────────────────────────────────────────────────────────────────────
# ...

# %%
result = fix(path)
# Out:
# ══════════════════════════════════════════════════════════════════════
#   DICOM FIX REPORT — 037503b94eb68a16587a78bce365e681.dicom
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
#   BEFORE FIX — issues found: 1
# ──────────────────────────────────────────────────────────────────────
#   • [INFO] Non-square image  → fixable (pad_square)
#
# ──────────────────────────────────────────────────────────────────────
#   FIXES APPLIED (1)
# ──────────────────────────────────────────────────────────────────────
#   ✓ 1. pad_square
#
# ──────────────────────────────────────────────────────────────────────
#   AFTER FIX — remaining issues: 0
# ──────────────────────────────────────────────────────────────────────
#   ✓ All issues resolved!
#
# ──────────────────────────────────────────────────────────────────────
#   OUTPUT IMAGE
# ...

# %%
explain(path, image=result["image"])
# Out:
# ══════════════════════════════════════════════════════════════════════
#   DICOM DIAGNOSTIC REPORT — 037503b94eb68a16587a78bce365e681.dicom
#   (analyzing fixed image — not the raw DICOM pixels)
# ══════════════════════════════════════════════════════════════════════
#
# ──────────────────────────────────────────────────────────────────────
#   OVERVIEW
# ──────────────────────────────────────────────────────────────────────
#   File         : 037503b94eb68a16587a78bce365e681.dicom  (12.05 MB)
#   Valid DICOM  : True   Has Pixels : True
#   Modality     : None   View : None
#   Dimensions   : 512 × 512  (square)
#   Photometric  : MONOCHROME2   Bits stored : 12
#   Rescale      : slope=1.0  intercept=0.0  ✓ none
#   Windowing    : center=1631.0  width=4260.0
#
# ──────────────────────────────────────────────────────────────────────
#   ISSUES FOUND (0)
# ──────────────────────────────────────────────────────────────────────
#   ✓ No issues detected.
#
# ...
